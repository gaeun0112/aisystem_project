# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/aisys24
# Out:
# /content/drive/MyDrive/aisys24

# %%
# !ls
# Out:
# CNN_final.ipynb  data  final_adam  final_SGD  trash..

# %% [markdown]
# ### CNN + MNIST & CIFAR-10

# %%
import numpy as np
import matplotlib.pyplot as plt
import time
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import DataLoader, random_split
from torchvision import datasets, transforms
from sklearn.metrics import f1_score
import pandas as pd

# %%
# Random seed 고정
seed = 42
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
np.random.seed(seed)

# %%
# 데이터셋 로드 및 전처리
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,))
]) # MNIST, (1, 28, 28)

transform_cifar = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
]) # CIFAR-10, (3, 32, 32)

# MNIST
train_dataset_mnist = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
test_dataset_mnist = datasets.MNIST(root='./data', train=False, download=True, transform=transform)

# Train/Validation split
train_size = int(0.8 * len(train_dataset_mnist))
validation_size = len(train_dataset_mnist) - train_size
train_dataset_mnist, val_dataset_mnist = random_split(train_dataset_mnist, [train_size, validation_size])

train_loader_mnist = DataLoader(dataset=train_dataset_mnist, batch_size=64, shuffle=True)
val_loader_mnist = DataLoader(dataset=val_dataset_mnist, batch_size=64, shuffle=False)
test_loader_mnist = DataLoader(dataset=test_dataset_mnist, batch_size=64, shuffle=False)

# CIFAR-10
train_dataset_cifar10 = datasets.CIFAR10(root='./data', train=True, download=True, transform=transform_cifar)
test_dataset_cifar10 = datasets.CIFAR10(root='./data', train=False, download=True, transform=transform_cifar)

# Train/Validation split
train_size = int(0.8 * len(train_dataset_cifar10))
validation_size = len(train_dataset_cifar10) - train_size
train_dataset_cifar10, val_dataset_cifar10 = random_split(train_dataset_cifar10, [train_size, validation_size])

train_loader_cifar10 = DataLoader(dataset=train_dataset_cifar10, batch_size=64, shuffle=True)
val_loader_cifar10 = DataLoader(dataset=val_dataset_cifar10, batch_size=64, shuffle=False)
test_loader_cifar10 = DataLoader(dataset=test_dataset_cifar10, batch_size=64, shuffle=False)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# https://pytorch.org/tutorials/beginner/blitz/cifar10_tutorial.html
class CNN(nn.Module):
    def __init__(self, activation_function):
        super(CNN, self).__init__()
        if dataset_name == 'MNIST':
          input_channels = 1
          fc1_input_size = 16 * 4 * 4
        else:
          input_channels = 3
          fc1_input_size = 16 * 5 * 5
        self.conv1 = nn.Conv2d(input_channels, 6, 5)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.fc1 = nn.Linear(fc1_input_size, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 10)
        self.activation_function = activation_function

    def forward(self, x):
        x = self.pool(self.activation_function(self.conv1(x)))
        x = self.pool(self.activation_function(self.conv2(x)))
        x = torch.flatten(x, 1)
        x = self.activation_function(self.fc1(x))
        x = self.activation_function(self.fc2(x))
        x = self.fc3(x)
        return x

# %%
dataset_name = 'MNIST'
cnn_model = CNN(F.relu)
for name, p in cnn_model.named_parameters():
	print(name)
# Out:
# conv1.weight
# conv1.bias
# conv2.weight
# conv2.bias
# fc1.weight
# fc1.bias
# fc2.weight
# fc2.bias
# fc3.weight
# fc3.bias

# %%
def init_weights(m):
    if isinstance(m, nn.Linear):
        torch.nn.init.xavier_uniform_(m.weight)
        m.bias.data.fill_(0.01)

# %%
def train_and_evaluate_model(activation_function, train_loader, val_loader, test_loader, epochs=50, patience=5):
    torch.manual_seed(42)
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model = CNN(activation_function).to(device)
    model.apply(init_weights)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)


    train_loss_history = []
    val_loss_history = []
    train_acc_history = []
    val_acc_history = []
    f1_scores = []
    epoch_times = []
    gradients = {name: [] for name, param in model.named_parameters() if param.requires_grad and 'weight' in name}
    # requires_grad==True이면 Gradient 계산 대상, bias 제외한 weight만 모으기 위해 조건 추가

    best_val_loss = float('inf')
    patience_counter = 0

    for epoch in range(epochs):
        model.train()
        start_time = time.time() # epoch마다 학습 시간 (시작)
        train_loss = 0
        correct = 0
        total = 0

        for batch_idx, (inputs, targets) in enumerate(train_loader):
            inputs, targets = inputs.to(device), targets.to(device)

            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            loss.backward()
            optimizer.step()

            train_loss += loss.item()
            _, predicted = outputs.max(1)
            total += targets.size(0)
            correct += predicted.eq(targets).sum().item()

        ############################################################
        # Collect gradients at the end of the epoch
        for name, param in model.named_parameters():
            if param.requires_grad and 'weight' in name:
                gradients[name].append(torch.norm(param.grad, p=2).item())
        ############################################################

        train_loss_history.append(train_loss / len(train_loader))
        train_acc_history.append(100. * correct / total)
        epoch_time = time.time() - start_time # 학습 시간 (종료)
        epoch_times.append(epoch_time)

        # Evaluation
        model.eval()
        val_loss = 0
        correct = 0
        total = 0
        all_targets = []
        all_predictions = []

        with torch.no_grad():
            for inputs, targets in val_loader:
                inputs, targets = inputs.to(device), targets.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, targets)
                val_loss += loss.item()
                _, predicted = outputs.max(1)
                total += targets.size(0)
                correct += predicted.eq(targets).sum().item()
                all_targets.extend(targets.cpu().numpy())
                all_predictions.extend(predicted.cpu().numpy())

        val_loss_history.append(val_loss / len(val_loader))
        val_acc_history.append(100. * correct / total)
        f1_scores.append(f1_score(all_targets, all_predictions, average='macro'))

        print(f'Epoch: {epoch+1}, Train Loss: {train_loss_history[-1]:.3f}, Val Loss: {val_loss_history[-1]:.3f}, Train Acc: {train_acc_history[-1]:.2f}%, Val Acc: {val_acc_history[-1]:.2f}%, F1 Score: {f1_scores[-1]:.3f}, Time: {epoch_time:.2f}s')

        # Early stopping check
        if val_loss_history[-1] < best_val_loss:
            best_val_loss = val_loss_history[-1]
            patience_counter = 0
        else:
            patience_counter += 1
            if patience_counter >= patience:
                print(f"Early stopping triggered at epoch {epoch+1}")
                break

    # Final evaluation on test set
    test_loss = 0
    correct = 0
    total = 0
    all_targets = []
    all_predictions = []

    with torch.no_grad():
        for inputs, targets in test_loader:
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total += targets.size(0)
            correct += predicted.eq(targets).sum().item()
            all_targets.extend(targets.cpu().numpy())
            all_predictions.extend(predicted.cpu().numpy())

    test_loss /= len(test_loader)
    test_acc = 100. * correct / total
    test_f1 = f1_score(all_targets, all_predictions, average='macro')

    print(f'Test Loss: {test_loss:.3f}, Test Acc: {test_acc:.2f}%, Test F1 Score: {test_f1:.3f}')


    results_df = pd.DataFrame({
        'epoch': list(range(1, len(train_loss_history) + 1)),
        'train_loss': train_loss_history,
        'val_loss': val_loss_history,
        'train_acc': train_acc_history,
        'val_acc': val_acc_history,
        'f1_scores': f1_scores,
        'epoch_times': epoch_times,
    })

    gradients_df = pd.DataFrame(gradients)

    return results_df, gradients_df, {
        'test_loss': test_loss,
        'test_acc': test_acc,
        'test_f1': test_f1
    }

# %%
dataset_name = 'MNIST'
cnn_model_mnist = CNN(F.relu)
print(cnn_model_mnist)
# Out:
# CNN(
#   (conv1): Conv2d(1, 6, kernel_size=(5, 5), stride=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(6, 16, kernel_size=(5, 5), stride=(1, 1))
#   (fc1): Linear(in_features=256, out_features=120, bias=True)
#   (fc2): Linear(in_features=120, out_features=84, bias=True)
#   (fc3): Linear(in_features=84, out_features=10, bias=True)
# )

# %%
dataset_name = 'CIFAR-10'
cnn_model_cifar10 = CNN(F.relu)
print(cnn_model_cifar10)
# Out:
# CNN(
#   (conv1): Conv2d(3, 6, kernel_size=(5, 5), stride=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(6, 16, kernel_size=(5, 5), stride=(1, 1))
#   (fc1): Linear(in_features=400, out_features=120, bias=True)
#   (fc2): Linear(in_features=120, out_features=84, bias=True)
#   (fc3): Linear(in_features=84, out_features=10, bias=True)
# )

# %%
activation_functions = {
    'sigmoid': torch.sigmoid,
    'ReLU': F.relu,
    'LReLU': F.leaky_relu,
    'ELU': F.elu,
    'SeLU': F.selu
}

results_mnist = {}
results_cifar10 = {}

for name, activation in activation_functions.items():
    print(f'Running experiment with {name} activation on MNIST')
    dataset_name = 'MNIST'
    results_mnist[name] = train_and_evaluate_model(activation, train_loader_mnist, val_loader_mnist, test_loader_mnist)

    print(f'Running experiment with {name} activation on CIFAR-10')
    dataset_name = 'CIFAR-10'
    results_cifar10[name] = train_and_evaluate_model(activation, train_loader_cifar10, val_loader_cifar10, test_loader_cifar10)
# Out:
# Running experiment with sigmoid activation on MNIST
# Epoch: 1, Train Loss: 2.307, Val Loss: 2.301, Train Acc: 11.10%, Val Acc: 12.65%, F1 Score: 0.042, Time: 15.95s
# Epoch: 2, Train Loss: 2.301, Val Loss: 2.300, Train Acc: 11.20%, Val Acc: 11.32%, F1 Score: 0.020, Time: 14.00s
# Epoch: 3, Train Loss: 2.301, Val Loss: 2.301, Train Acc: 11.20%, Val Acc: 9.78%, F1 Score: 0.018, Time: 14.15s
# Epoch: 4, Train Loss: 2.300, Val Loss: 2.299, Train Acc: 11.37%, Val Acc: 10.68%, F1 Score: 0.019, Time: 14.08s
# Epoch: 5, Train Loss: 2.299, Val Loss: 2.298, Train Acc: 11.64%, Val Acc: 11.32%, F1 Score: 0.020, Time: 14.10s
# Epoch: 6, Train Loss: 2.298, Val Loss: 2.297, Train Acc: 12.12%, Val Acc: 11.32%, F1 Score: 0.020, Time: 14.44s
# Epoch: 7, Train Loss: 2.297, Val Loss: 2.296, Train Acc: 12.27%, Val Acc: 11.32%, F1 Score: 0.020, Time: 15.27s
# Epoch: 8, Train Loss: 2.295, Val Loss: 2.293, Train Acc: 12.61%, Val Acc: 11.32%, F1 Score: 0.020, Time: 14.02s
# Epoch: 9, Train Loss: 2.292, Val Loss: 2.291, Train Acc: 12.86%, Val Acc: 11.32%, F1 Score: 0.020, Time: 13.97s
# Epoch: 10, Train Loss: 2.289, Val Loss: 2.286, Train Acc: 14.30%, Val Acc: 11.32%, F1 Score: 0.020, Time: 14.09s
# Epoch: 11, Train Loss: 2.284, Val Loss: 2.280, Train Acc: 14.15%, Val Acc: 24.43%, F1 Score: 0.162, Time: 14.04s
# Epoch: 12, Train Loss: 2.276, Val Loss: 2.270, Train Acc: 17.70%, Val Acc: 21.38%, F1 Score: 0.100, Time: 14.42s
# Epoch: 13, Train Loss: 2.263, Val Loss: 2.254, Train Acc: 22.96%, Val Acc: 14.58%, F1 Score: 0.072, Time: 14.04s
# Epoch: 14, Train Loss: 2.241, Val Loss: 2.223, Train Acc: 27.64%, Val Acc: 29.17%, F1 Score: 0.215, Time: 14.06s
# Epoch: 15, Train Loss: 2.198, Val Loss: 2.166, Train Acc: 33.61%, Val Acc: 44.58%, F1 Score: 0.367, Time: 14.01s
# Epoch: 16, Train Loss: 2.116, Val Loss: 2.054, Train Acc: 40.28%, Val Acc: 41.67%, F1 Score: 0.368, Time: 14.15s
# Epoch: 17, Train Loss: 1.973, Val Loss: 1.886, Train Acc: 46.22%, Val Acc: 48.64%, F1 Score: 0.426, Time: 14.00s
# Epoch: 18, Train Loss: 1.794, Val Loss: 1.700, Train Acc: 53.70%, Val Acc: 54.71%, F1 Score: 0.500, Time: 14.40s
# Epoch: 19, Train Loss: 1.597, Val Loss: 1.495, Train Acc: 59.21%, Val Acc: 61.43%, F1 Score: 0.569, Time: 14.63s
# Epoch: 20, Train Loss: 1.382, Val Loss: 1.280, Train Acc: 65.02%, Val Acc: 66.52%, F1 Score: 0.635, Time: 16.27s
# Epoch: 21, Train Loss: 1.177, Val Loss: 1.095, Train Acc: 69.78%, Val Acc: 71.56%, F1 Score: 0.699, Time: 14.78s
# Epoch: 22, Train Loss: 1.010, Val Loss: 0.950, Train Acc: 73.95%, Val Acc: 75.06%, F1 Score: 0.739, Time: 14.46s
# Epoch: 23, Train Loss: 0.881, Val Loss: 0.837, Train Acc: 77.30%, Val Acc: 78.17%, F1 Score: 0.774, Time: 14.52s
# Epoch: 24, Train Loss: 0.779, Val Loss: 0.748, Train Acc: 79.95%, Val Acc: 81.05%, F1 Score: 0.806, Time: 14.71s
# Epoch: 25, Train Loss: 0.697, Val Loss: 0.674, Train Acc: 81.95%, Val Acc: 82.60%, F1 Score: 0.823, Time: 14.50s
# Epoch: 26, Train Loss: 0.630, Val Loss: 0.613, Train Acc: 83.51%, Val Acc: 84.01%, F1 Score: 0.837, Time: 14.78s
# Epoch: 27, Train Loss: 0.574, Val Loss: 0.563, Train Acc: 84.86%, Val Acc: 85.16%, F1 Score: 0.849, Time: 14.81s
# Epoch: 28, Train Loss: 0.528, Val Loss: 0.520, Train Acc: 85.96%, Val Acc: 86.17%, F1 Score: 0.860, Time: 14.66s
# Epoch: 29, Train Loss: 0.489, Val Loss: 0.485, Train Acc: 86.95%, Val Acc: 86.91%, F1 Score: 0.867, Time: 14.59s
# Epoch: 30, Train Loss: 0.456, Val Loss: 0.455, Train Acc: 87.78%, Val Acc: 87.58%, F1 Score: 0.874, Time: 14.20s
# Epoch: 31, Train Loss: 0.428, Val Loss: 0.430, Train Acc: 88.48%, Val Acc: 88.35%, F1 Score: 0.882, Time: 14.80s
# Epoch: 32, Train Loss: 0.404, Val Loss: 0.407, Train Acc: 89.01%, Val Acc: 88.73%, F1 Score: 0.886, Time: 14.48s
# Epoch: 33, Train Loss: 0.383, Val Loss: 0.389, Train Acc: 89.51%, Val Acc: 89.38%, F1 Score: 0.892, Time: 14.61s
# Epoch: 34, Train Loss: 0.365, Val Loss: 0.371, Train Acc: 89.98%, Val Acc: 89.76%, F1 Score: 0.896, Time: 14.51s
# Epoch: 35, Train Loss: 0.349, Val Loss: 0.356, Train Acc: 90.36%, Val Acc: 90.09%, F1 Score: 0.900, Time: 14.61s
# Epoch: 36, Train Loss: 0.334, Val Loss: 0.342, Train Acc: 90.72%, Val Acc: 90.33%, F1 Score: 0.902, Time: 14.56s
# Epoch: 37, Train Loss: 0.321, Val Loss: 0.330, Train Acc: 91.02%, Val Acc: 90.72%, F1 Score: 0.906, Time: 14.63s
# Epoch: 38, Train Loss: 0.310, Val Loss: 0.319, Train Acc: 91.38%, Val Acc: 90.92%, F1 Score: 0.908, Time: 14.49s
# Epoch: 39, Train Loss: 0.299, Val Loss: 0.308, Train Acc: 91.62%, Val Acc: 91.31%, F1 Score: 0.912, Time: 14.57s
# Epoch: 40, Train Loss: 0.289, Val Loss: 0.299, Train Acc: 91.91%, Val Acc: 91.58%, F1 Score: 0.915, Time: 14.47s
# Epoch: 41, Train Loss: 0.280, Val Loss: 0.290, Train Acc: 92.12%, Val Acc: 91.83%, F1 Score: 0.917, Time: 14.62s
# Epoch: 42, Train Loss: 0.272, Val Loss: 0.282, Train Acc: 92.39%, Val Acc: 92.03%, F1 Score: 0.919, Time: 14.51s
# Epoch: 43, Train Loss: 0.264, Val Loss: 0.274, Train Acc: 92.64%, Val Acc: 92.24%, F1 Score: 0.921, Time: 14.80s
# Epoch: 44, Train Loss: 0.257, Val Loss: 0.267, Train Acc: 92.84%, Val Acc: 92.43%, F1 Score: 0.923, Time: 14.61s
# Epoch: 45, Train Loss: 0.250, Val Loss: 0.260, Train Acc: 93.03%, Val Acc: 92.58%, F1 Score: 0.925, Time: 15.79s
# Epoch: 46, Train Loss: 0.243, Val Loss: 0.254, Train Acc: 93.16%, Val Acc: 92.82%, F1 Score: 0.927, Time: 14.54s
# Epoch: 47, Train Loss: 0.237, Val Loss: 0.247, Train Acc: 93.32%, Val Acc: 92.86%, F1 Score: 0.928, Time: 14.65s
# Epoch: 48, Train Loss: 0.231, Val Loss: 0.242, Train Acc: 93.49%, Val Acc: 93.06%, F1 Score: 0.930, Time: 14.62s
# Epoch: 49, Train Loss: 0.226, Val Loss: 0.236, Train Acc: 93.66%, Val Acc: 93.17%, F1 Score: 0.931, Time: 14.42s
# Epoch: 50, Train Loss: 0.221, Val Loss: 0.231, Train Acc: 93.75%, Val Acc: 93.28%, F1 Score: 0.932, Time: 14.66s
# Test Loss: 0.207, Test Acc: 94.22%, Test F1 Score: 0.942
# Running experiment with sigmoid activation on CIFAR-10
# Epoch: 1, Train Loss: 2.308, Val Loss: 2.303, Train Acc: 9.99%, Val Acc: 10.28%, F1 Score: 0.019, Time: 14.14s
# Epoch: 2, Train Loss: 2.303, Val Loss: 2.303, Train Acc: 10.00%, Val Acc: 10.17%, F1 Score: 0.018, Time: 14.03s
# Epoch: 3, Train Loss: 2.303, Val Loss: 2.303, Train Acc: 10.35%, Val Acc: 10.28%, F1 Score: 0.019, Time: 14.22s
# Epoch: 4, Train Loss: 2.303, Val Loss: 2.303, Train Acc: 10.11%, Val Acc: 9.99%, F1 Score: 0.018, Time: 14.26s
# Epoch: 5, Train Loss: 2.303, Val Loss: 2.303, Train Acc: 10.18%, Val Acc: 9.90%, F1 Score: 0.018, Time: 14.11s
# Epoch: 6, Train Loss: 2.303, Val Loss: 2.303, Train Acc: 9.73%, Val Acc: 9.41%, F1 Score: 0.017, Time: 14.63s
# Epoch: 7, Train Loss: 2.303, Val Loss: 2.303, Train Acc: 10.14%, Val Acc: 9.90%, F1 Score: 0.018, Time: 13.84s
# Epoch: 8, Train Loss: 2.303, Val Loss: 2.302, Train Acc: 10.16%, Val Acc: 9.41%, F1 Score: 0.017, Time: 13.79s
# Epoch: 9, Train Loss: 2.302, Val Loss: 2.304, Train Acc: 10.52%, Val Acc: 9.90%, F1 Score: 0.018, Time: 15.77s
# Epoch: 10, Train Loss: 2.302, Val Loss: 2.302, Train Acc: 10.33%, Val Acc: 9.90%, F1 Score: 0.018, Time: 14.38s
# Epoch: 11, Train Loss: 2.302, Val Loss: 2.302, Train Acc: 10.74%, Val Acc: 12.96%, F1 Score: 0.049, Time: 14.84s
# Epoch: 12, Train Loss: 2.302, Val Loss: 2.301, Train Acc: 10.64%, Val Acc: 10.81%, F1 Score: 0.033, Time: 14.25s
# Epoch: 13, Train Loss: 2.301, Val Loss: 2.301, Train Acc: 11.23%, Val Acc: 10.05%, F1 Score: 0.028, Time: 14.43s
# Epoch: 14, Train Loss: 2.300, Val Loss: 2.299, Train Acc: 10.96%, Val Acc: 10.18%, F1 Score: 0.018, Time: 14.04s
# Epoch: 15, Train Loss: 2.299, Val Loss: 2.298, Train Acc: 12.36%, Val Acc: 12.83%, F1 Score: 0.049, Time: 14.14s
# Epoch: 16, Train Loss: 2.297, Val Loss: 2.297, Train Acc: 12.83%, Val Acc: 12.89%, F1 Score: 0.042, Time: 14.30s
# Epoch: 17, Train Loss: 2.294, Val Loss: 2.292, Train Acc: 13.58%, Val Acc: 15.12%, F1 Score: 0.066, Time: 14.29s
# Epoch: 18, Train Loss: 2.290, Val Loss: 2.287, Train Acc: 14.55%, Val Acc: 15.98%, F1 Score: 0.078, Time: 14.33s
# Epoch: 19, Train Loss: 2.283, Val Loss: 2.278, Train Acc: 15.40%, Val Acc: 14.06%, F1 Score: 0.070, Time: 14.08s
# Epoch: 20, Train Loss: 2.270, Val Loss: 2.261, Train Acc: 17.18%, Val Acc: 16.39%, F1 Score: 0.083, Time: 14.18s
# Epoch: 21, Train Loss: 2.248, Val Loss: 2.235, Train Acc: 17.82%, Val Acc: 17.34%, F1 Score: 0.089, Time: 14.18s
# Epoch: 22, Train Loss: 2.217, Val Loss: 2.201, Train Acc: 18.47%, Val Acc: 18.15%, F1 Score: 0.124, Time: 15.63s
# Epoch: 23, Train Loss: 2.181, Val Loss: 2.166, Train Acc: 19.51%, Val Acc: 20.31%, F1 Score: 0.147, Time: 14.24s
# Epoch: 24, Train Loss: 2.147, Val Loss: 2.136, Train Acc: 20.76%, Val Acc: 21.28%, F1 Score: 0.169, Time: 14.17s
# Epoch: 25, Train Loss: 2.115, Val Loss: 2.107, Train Acc: 21.21%, Val Acc: 22.15%, F1 Score: 0.167, Time: 14.24s
# Epoch: 26, Train Loss: 2.088, Val Loss: 2.087, Train Acc: 21.89%, Val Acc: 20.37%, F1 Score: 0.141, Time: 14.08s
# Epoch: 27, Train Loss: 2.071, Val Loss: 2.075, Train Acc: 21.85%, Val Acc: 21.27%, F1 Score: 0.162, Time: 14.04s
# Epoch: 28, Train Loss: 2.062, Val Loss: 2.068, Train Acc: 22.42%, Val Acc: 22.00%, F1 Score: 0.174, Time: 14.10s
# Epoch: 29, Train Loss: 2.056, Val Loss: 2.063, Train Acc: 22.48%, Val Acc: 21.43%, F1 Score: 0.162, Time: 14.09s
# Epoch: 30, Train Loss: 2.051, Val Loss: 2.060, Train Acc: 22.55%, Val Acc: 22.00%, F1 Score: 0.170, Time: 14.19s
# Epoch: 31, Train Loss: 2.047, Val Loss: 2.053, Train Acc: 22.92%, Val Acc: 22.98%, F1 Score: 0.185, Time: 14.17s
# Epoch: 32, Train Loss: 2.042, Val Loss: 2.049, Train Acc: 23.12%, Val Acc: 24.22%, F1 Score: 0.202, Time: 14.14s
# Epoch: 33, Train Loss: 2.038, Val Loss: 2.045, Train Acc: 23.36%, Val Acc: 22.80%, F1 Score: 0.176, Time: 14.16s
# Epoch: 34, Train Loss: 2.034, Val Loss: 2.040, Train Acc: 23.79%, Val Acc: 23.46%, F1 Score: 0.175, Time: 14.30s
# Epoch: 35, Train Loss: 2.029, Val Loss: 2.036, Train Acc: 24.18%, Val Acc: 24.80%, F1 Score: 0.216, Time: 16.07s
# Epoch: 36, Train Loss: 2.024, Val Loss: 2.031, Train Acc: 24.07%, Val Acc: 24.96%, F1 Score: 0.203, Time: 14.06s
# Epoch: 37, Train Loss: 2.020, Val Loss: 2.027, Train Acc: 24.66%, Val Acc: 23.47%, F1 Score: 0.177, Time: 14.16s
# Epoch: 38, Train Loss: 2.015, Val Loss: 2.022, Train Acc: 24.88%, Val Acc: 25.59%, F1 Score: 0.209, Time: 14.16s
# Epoch: 39, Train Loss: 2.010, Val Loss: 2.017, Train Acc: 25.19%, Val Acc: 24.96%, F1 Score: 0.213, Time: 14.19s
# Epoch: 40, Train Loss: 2.006, Val Loss: 2.013, Train Acc: 25.43%, Val Acc: 24.71%, F1 Score: 0.207, Time: 14.07s
# Epoch: 41, Train Loss: 2.001, Val Loss: 2.006, Train Acc: 25.80%, Val Acc: 26.57%, F1 Score: 0.234, Time: 14.18s
# Epoch: 42, Train Loss: 1.997, Val Loss: 2.003, Train Acc: 26.26%, Val Acc: 24.91%, F1 Score: 0.200, Time: 14.21s
# Epoch: 43, Train Loss: 1.992, Val Loss: 1.997, Train Acc: 26.45%, Val Acc: 26.36%, F1 Score: 0.233, Time: 14.12s
# Epoch: 44, Train Loss: 1.987, Val Loss: 1.993, Train Acc: 26.41%, Val Acc: 26.57%, F1 Score: 0.227, Time: 14.28s
# Epoch: 45, Train Loss: 1.982, Val Loss: 1.986, Train Acc: 26.70%, Val Acc: 26.86%, F1 Score: 0.238, Time: 14.12s
# Epoch: 46, Train Loss: 1.977, Val Loss: 1.982, Train Acc: 27.32%, Val Acc: 26.97%, F1 Score: 0.239, Time: 14.17s
# Epoch: 47, Train Loss: 1.972, Val Loss: 1.978, Train Acc: 27.62%, Val Acc: 27.09%, F1 Score: 0.235, Time: 14.21s
# Epoch: 48, Train Loss: 1.966, Val Loss: 1.970, Train Acc: 27.73%, Val Acc: 27.44%, F1 Score: 0.239, Time: 14.14s
# Epoch: 49, Train Loss: 1.960, Val Loss: 1.965, Train Acc: 27.89%, Val Acc: 27.40%, F1 Score: 0.240, Time: 15.57s
# Epoch: 50, Train Loss: 1.954, Val Loss: 1.958, Train Acc: 28.34%, Val Acc: 27.36%, F1 Score: 0.227, Time: 14.16s
# Test Loss: 1.945, Test Acc: 28.45%, Test F1 Score: 0.236
# Running experiment with ReLU activation on MNIST
# Epoch: 1, Train Loss: 0.514, Val Loss: 0.205, Train Acc: 85.08%, Val Acc: 93.67%, F1 Score: 0.936, Time: 14.72s
# Epoch: 2, Train Loss: 0.153, Val Loss: 0.151, Train Acc: 95.35%, Val Acc: 95.47%, F1 Score: 0.954, Time: 14.49s
# Epoch: 3, Train Loss: 0.114, Val Loss: 0.104, Train Acc: 96.54%, Val Acc: 96.77%, F1 Score: 0.967, Time: 14.46s
# Epoch: 4, Train Loss: 0.095, Val Loss: 0.102, Train Acc: 97.06%, Val Acc: 96.86%, F1 Score: 0.968, Time: 14.39s
# Epoch: 5, Train Loss: 0.082, Val Loss: 0.085, Train Acc: 97.54%, Val Acc: 97.37%, F1 Score: 0.973, Time: 14.49s
# Epoch: 6, Train Loss: 0.072, Val Loss: 0.077, Train Acc: 97.81%, Val Acc: 97.57%, F1 Score: 0.975, Time: 14.38s
# Epoch: 7, Train Loss: 0.064, Val Loss: 0.073, Train Acc: 98.04%, Val Acc: 97.65%, F1 Score: 0.976, Time: 14.41s
# Epoch: 8, Train Loss: 0.059, Val Loss: 0.071, Train Acc: 98.23%, Val Acc: 97.93%, F1 Score: 0.979, Time: 14.43s
# Epoch: 9, Train Loss: 0.054, Val Loss: 0.071, Train Acc: 98.33%, Val Acc: 97.86%, F1 Score: 0.978, Time: 14.56s
# Epoch: 10, Train Loss: 0.052, Val Loss: 0.068, Train Acc: 98.42%, Val Acc: 97.77%, F1 Score: 0.978, Time: 14.38s
# Epoch: 11, Train Loss: 0.046, Val Loss: 0.062, Train Acc: 98.59%, Val Acc: 98.02%, F1 Score: 0.980, Time: 14.47s
# Epoch: 12, Train Loss: 0.043, Val Loss: 0.061, Train Acc: 98.64%, Val Acc: 98.09%, F1 Score: 0.981, Time: 15.39s
# Epoch: 13, Train Loss: 0.041, Val Loss: 0.070, Train Acc: 98.66%, Val Acc: 97.78%, F1 Score: 0.978, Time: 14.51s
# Epoch: 14, Train Loss: 0.039, Val Loss: 0.068, Train Acc: 98.80%, Val Acc: 97.83%, F1 Score: 0.978, Time: 14.40s
# Epoch: 15, Train Loss: 0.037, Val Loss: 0.056, Train Acc: 98.87%, Val Acc: 98.28%, F1 Score: 0.983, Time: 14.43s
# Epoch: 16, Train Loss: 0.034, Val Loss: 0.053, Train Acc: 98.91%, Val Acc: 98.33%, F1 Score: 0.983, Time: 14.47s
# Epoch: 17, Train Loss: 0.032, Val Loss: 0.055, Train Acc: 99.00%, Val Acc: 98.33%, F1 Score: 0.983, Time: 14.51s
# Epoch: 18, Train Loss: 0.029, Val Loss: 0.055, Train Acc: 99.09%, Val Acc: 98.27%, F1 Score: 0.983, Time: 14.37s
# Epoch: 19, Train Loss: 0.028, Val Loss: 0.053, Train Acc: 99.16%, Val Acc: 98.37%, F1 Score: 0.984, Time: 14.39s
# Epoch: 20, Train Loss: 0.026, Val Loss: 0.055, Train Acc: 99.18%, Val Acc: 98.40%, F1 Score: 0.984, Time: 14.46s
# Epoch: 21, Train Loss: 0.024, Val Loss: 0.054, Train Acc: 99.28%, Val Acc: 98.38%, F1 Score: 0.984, Time: 14.60s
# Epoch: 22, Train Loss: 0.024, Val Loss: 0.053, Train Acc: 99.25%, Val Acc: 98.38%, F1 Score: 0.984, Time: 14.47s
# Epoch: 23, Train Loss: 0.022, Val Loss: 0.057, Train Acc: 99.35%, Val Acc: 98.33%, F1 Score: 0.983, Time: 14.41s
# Epoch: 24, Train Loss: 0.022, Val Loss: 0.053, Train Acc: 99.30%, Val Acc: 98.42%, F1 Score: 0.984, Time: 14.51s
# Epoch: 25, Train Loss: 0.019, Val Loss: 0.053, Train Acc: 99.40%, Val Acc: 98.53%, F1 Score: 0.985, Time: 16.35s
# Epoch: 26, Train Loss: 0.018, Val Loss: 0.063, Train Acc: 99.48%, Val Acc: 98.19%, F1 Score: 0.982, Time: 14.53s
# Epoch: 27, Train Loss: 0.018, Val Loss: 0.059, Train Acc: 99.45%, Val Acc: 98.28%, F1 Score: 0.983, Time: 14.49s
# Early stopping triggered at epoch 27
# Test Loss: 0.054, Test Acc: 98.35%, Test F1 Score: 0.983
# Running experiment with ReLU activation on CIFAR-10
# Epoch: 1, Train Loss: 2.095, Val Loss: 1.878, Train Acc: 24.26%, Val Acc: 32.28%, F1 Score: 0.309, Time: 14.38s
# Epoch: 2, Train Loss: 1.754, Val Loss: 1.647, Train Acc: 36.87%, Val Acc: 40.79%, F1 Score: 0.399, Time: 14.38s
# Epoch: 3, Train Loss: 1.570, Val Loss: 1.550, Train Acc: 42.84%, Val Acc: 43.43%, F1 Score: 0.428, Time: 14.17s
# Epoch: 4, Train Loss: 1.487, Val Loss: 1.486, Train Acc: 46.10%, Val Acc: 45.78%, F1 Score: 0.457, Time: 14.14s
# Epoch: 5, Train Loss: 1.432, Val Loss: 1.428, Train Acc: 48.44%, Val Acc: 48.80%, F1 Score: 0.482, Time: 14.31s
# Epoch: 6, Train Loss: 1.383, Val Loss: 1.386, Train Acc: 50.35%, Val Acc: 50.00%, F1 Score: 0.496, Time: 14.02s
# Epoch: 7, Train Loss: 1.342, Val Loss: 1.364, Train Acc: 51.86%, Val Acc: 51.46%, F1 Score: 0.519, Time: 14.18s
# Epoch: 8, Train Loss: 1.303, Val Loss: 1.326, Train Acc: 53.66%, Val Acc: 52.75%, F1 Score: 0.521, Time: 14.34s
# Epoch: 9, Train Loss: 1.268, Val Loss: 1.296, Train Acc: 55.09%, Val Acc: 54.26%, F1 Score: 0.545, Time: 14.22s
# Epoch: 10, Train Loss: 1.239, Val Loss: 1.313, Train Acc: 56.19%, Val Acc: 53.09%, F1 Score: 0.522, Time: 14.13s
# Epoch: 11, Train Loss: 1.216, Val Loss: 1.276, Train Acc: 57.05%, Val Acc: 54.20%, F1 Score: 0.540, Time: 15.44s
# Epoch: 12, Train Loss: 1.189, Val Loss: 1.221, Train Acc: 58.22%, Val Acc: 56.91%, F1 Score: 0.569, Time: 14.30s
# Epoch: 13, Train Loss: 1.166, Val Loss: 1.225, Train Acc: 58.94%, Val Acc: 57.19%, F1 Score: 0.574, Time: 14.24s
# Epoch: 14, Train Loss: 1.144, Val Loss: 1.197, Train Acc: 59.58%, Val Acc: 57.97%, F1 Score: 0.578, Time: 14.15s
# Epoch: 15, Train Loss: 1.124, Val Loss: 1.193, Train Acc: 60.32%, Val Acc: 58.13%, F1 Score: 0.582, Time: 14.24s
# Epoch: 16, Train Loss: 1.107, Val Loss: 1.192, Train Acc: 61.11%, Val Acc: 58.10%, F1 Score: 0.579, Time: 14.31s
# Epoch: 17, Train Loss: 1.089, Val Loss: 1.174, Train Acc: 61.80%, Val Acc: 58.71%, F1 Score: 0.586, Time: 14.12s
# Epoch: 18, Train Loss: 1.073, Val Loss: 1.172, Train Acc: 62.27%, Val Acc: 58.97%, F1 Score: 0.589, Time: 14.10s
# Epoch: 19, Train Loss: 1.059, Val Loss: 1.163, Train Acc: 62.84%, Val Acc: 59.55%, F1 Score: 0.592, Time: 14.29s
# Epoch: 20, Train Loss: 1.043, Val Loss: 1.145, Train Acc: 63.59%, Val Acc: 60.14%, F1 Score: 0.603, Time: 14.38s
# Epoch: 21, Train Loss: 1.028, Val Loss: 1.136, Train Acc: 63.99%, Val Acc: 60.43%, F1 Score: 0.601, Time: 14.15s
# Epoch: 22, Train Loss: 1.017, Val Loss: 1.169, Train Acc: 64.36%, Val Acc: 60.00%, F1 Score: 0.603, Time: 14.26s
# Epoch: 23, Train Loss: 1.003, Val Loss: 1.118, Train Acc: 65.00%, Val Acc: 60.99%, F1 Score: 0.608, Time: 14.28s
# Epoch: 24, Train Loss: 0.986, Val Loss: 1.129, Train Acc: 65.68%, Val Acc: 60.96%, F1 Score: 0.606, Time: 14.25s
# Epoch: 25, Train Loss: 0.973, Val Loss: 1.129, Train Acc: 66.06%, Val Acc: 61.30%, F1 Score: 0.615, Time: 15.66s
# Epoch: 26, Train Loss: 0.963, Val Loss: 1.112, Train Acc: 66.28%, Val Acc: 61.53%, F1 Score: 0.615, Time: 14.21s
# Epoch: 27, Train Loss: 0.949, Val Loss: 1.143, Train Acc: 66.74%, Val Acc: 60.37%, F1 Score: 0.608, Time: 14.19s
# Epoch: 28, Train Loss: 0.943, Val Loss: 1.143, Train Acc: 67.03%, Val Acc: 60.69%, F1 Score: 0.610, Time: 14.24s
# Epoch: 29, Train Loss: 0.927, Val Loss: 1.109, Train Acc: 67.51%, Val Acc: 62.16%, F1 Score: 0.619, Time: 14.20s
# Epoch: 30, Train Loss: 0.915, Val Loss: 1.112, Train Acc: 68.09%, Val Acc: 61.83%, F1 Score: 0.616, Time: 14.34s
# Epoch: 31, Train Loss: 0.902, Val Loss: 1.113, Train Acc: 68.46%, Val Acc: 61.70%, F1 Score: 0.619, Time: 14.42s
# Epoch: 32, Train Loss: 0.893, Val Loss: 1.128, Train Acc: 68.78%, Val Acc: 61.77%, F1 Score: 0.612, Time: 14.60s
# Epoch: 33, Train Loss: 0.883, Val Loss: 1.102, Train Acc: 69.29%, Val Acc: 62.39%, F1 Score: 0.623, Time: 14.59s
# Epoch: 34, Train Loss: 0.866, Val Loss: 1.109, Train Acc: 69.74%, Val Acc: 62.15%, F1 Score: 0.625, Time: 14.52s
# Epoch: 35, Train Loss: 0.857, Val Loss: 1.106, Train Acc: 70.19%, Val Acc: 62.15%, F1 Score: 0.622, Time: 14.48s
# Epoch: 36, Train Loss: 0.853, Val Loss: 1.103, Train Acc: 70.09%, Val Acc: 62.46%, F1 Score: 0.626, Time: 14.46s
# Epoch: 37, Train Loss: 0.838, Val Loss: 1.095, Train Acc: 70.81%, Val Acc: 63.00%, F1 Score: 0.630, Time: 14.40s
# Epoch: 38, Train Loss: 0.824, Val Loss: 1.114, Train Acc: 71.28%, Val Acc: 62.21%, F1 Score: 0.622, Time: 15.60s
# Epoch: 39, Train Loss: 0.817, Val Loss: 1.101, Train Acc: 71.30%, Val Acc: 62.80%, F1 Score: 0.627, Time: 14.20s
# Epoch: 40, Train Loss: 0.808, Val Loss: 1.143, Train Acc: 71.94%, Val Acc: 62.50%, F1 Score: 0.622, Time: 14.26s
# Epoch: 41, Train Loss: 0.795, Val Loss: 1.102, Train Acc: 72.31%, Val Acc: 62.67%, F1 Score: 0.628, Time: 14.20s
# Epoch: 42, Train Loss: 0.784, Val Loss: 1.130, Train Acc: 72.73%, Val Acc: 62.76%, F1 Score: 0.629, Time: 14.19s
# Early stopping triggered at epoch 42
# Test Loss: 1.137, Test Acc: 62.30%, Test F1 Score: 0.624
# Running experiment with LReLU activation on MNIST
# Epoch: 1, Train Loss: 0.512, Val Loss: 0.201, Train Acc: 85.17%, Val Acc: 93.97%, F1 Score: 0.939, Time: 14.51s
# Epoch: 2, Train Loss: 0.153, Val Loss: 0.155, Train Acc: 95.36%, Val Acc: 95.51%, F1 Score: 0.955, Time: 14.37s
# Epoch: 3, Train Loss: 0.115, Val Loss: 0.105, Train Acc: 96.53%, Val Acc: 96.78%, F1 Score: 0.968, Time: 14.25s
# Epoch: 4, Train Loss: 0.095, Val Loss: 0.101, Train Acc: 97.07%, Val Acc: 96.91%, F1 Score: 0.969, Time: 14.31s
# Epoch: 5, Train Loss: 0.082, Val Loss: 0.086, Train Acc: 97.58%, Val Acc: 97.38%, F1 Score: 0.974, Time: 14.49s
# Epoch: 6, Train Loss: 0.072, Val Loss: 0.078, Train Acc: 97.79%, Val Acc: 97.49%, F1 Score: 0.975, Time: 14.45s
# Epoch: 7, Train Loss: 0.065, Val Loss: 0.073, Train Acc: 98.03%, Val Acc: 97.72%, F1 Score: 0.977, Time: 14.35s
# Epoch: 8, Train Loss: 0.059, Val Loss: 0.070, Train Acc: 98.24%, Val Acc: 97.93%, F1 Score: 0.979, Time: 14.41s
# Epoch: 9, Train Loss: 0.054, Val Loss: 0.072, Train Acc: 98.32%, Val Acc: 97.89%, F1 Score: 0.979, Time: 14.50s
# Epoch: 10, Train Loss: 0.052, Val Loss: 0.068, Train Acc: 98.40%, Val Acc: 97.85%, F1 Score: 0.978, Time: 16.33s
# Epoch: 11, Train Loss: 0.046, Val Loss: 0.063, Train Acc: 98.59%, Val Acc: 97.96%, F1 Score: 0.979, Time: 14.44s
# Epoch: 12, Train Loss: 0.043, Val Loss: 0.060, Train Acc: 98.62%, Val Acc: 98.15%, F1 Score: 0.981, Time: 14.35s
# Epoch: 13, Train Loss: 0.041, Val Loss: 0.069, Train Acc: 98.69%, Val Acc: 97.87%, F1 Score: 0.979, Time: 14.55s
# Epoch: 14, Train Loss: 0.039, Val Loss: 0.066, Train Acc: 98.83%, Val Acc: 97.92%, F1 Score: 0.979, Time: 14.51s
# Epoch: 15, Train Loss: 0.036, Val Loss: 0.056, Train Acc: 98.90%, Val Acc: 98.23%, F1 Score: 0.982, Time: 14.41s
# Epoch: 16, Train Loss: 0.033, Val Loss: 0.055, Train Acc: 98.99%, Val Acc: 98.32%, F1 Score: 0.983, Time: 14.46s
# Epoch: 17, Train Loss: 0.031, Val Loss: 0.057, Train Acc: 99.04%, Val Acc: 98.23%, F1 Score: 0.982, Time: 14.33s
# Epoch: 18, Train Loss: 0.029, Val Loss: 0.055, Train Acc: 99.07%, Val Acc: 98.26%, F1 Score: 0.982, Time: 14.67s
# Epoch: 19, Train Loss: 0.028, Val Loss: 0.053, Train Acc: 99.14%, Val Acc: 98.38%, F1 Score: 0.984, Time: 14.61s
# Epoch: 20, Train Loss: 0.026, Val Loss: 0.056, Train Acc: 99.15%, Val Acc: 98.33%, F1 Score: 0.983, Time: 14.49s
# Epoch: 21, Train Loss: 0.024, Val Loss: 0.055, Train Acc: 99.27%, Val Acc: 98.37%, F1 Score: 0.984, Time: 14.63s
# Epoch: 22, Train Loss: 0.024, Val Loss: 0.053, Train Acc: 99.25%, Val Acc: 98.36%, F1 Score: 0.984, Time: 14.49s
# Epoch: 23, Train Loss: 0.022, Val Loss: 0.057, Train Acc: 99.33%, Val Acc: 98.41%, F1 Score: 0.984, Time: 14.63s
# Epoch: 24, Train Loss: 0.022, Val Loss: 0.053, Train Acc: 99.31%, Val Acc: 98.39%, F1 Score: 0.984, Time: 15.76s
# Epoch: 25, Train Loss: 0.019, Val Loss: 0.053, Train Acc: 99.40%, Val Acc: 98.51%, F1 Score: 0.985, Time: 14.51s
# Epoch: 26, Train Loss: 0.018, Val Loss: 0.065, Train Acc: 99.48%, Val Acc: 98.15%, F1 Score: 0.981, Time: 14.35s
# Epoch: 27, Train Loss: 0.018, Val Loss: 0.062, Train Acc: 99.46%, Val Acc: 98.22%, F1 Score: 0.982, Time: 14.55s
# Early stopping triggered at epoch 27
# Test Loss: 0.057, Test Acc: 98.26%, Test F1 Score: 0.982
# Running experiment with LReLU activation on CIFAR-10
# Epoch: 1, Train Loss: 2.093, Val Loss: 1.877, Train Acc: 24.31%, Val Acc: 32.09%, F1 Score: 0.305, Time: 14.34s
# Epoch: 2, Train Loss: 1.753, Val Loss: 1.650, Train Acc: 36.91%, Val Acc: 40.51%, F1 Score: 0.395, Time: 14.34s
# Epoch: 3, Train Loss: 1.570, Val Loss: 1.547, Train Acc: 42.87%, Val Acc: 43.82%, F1 Score: 0.432, Time: 14.53s
# Epoch: 4, Train Loss: 1.486, Val Loss: 1.481, Train Acc: 46.23%, Val Acc: 45.89%, F1 Score: 0.458, Time: 14.37s
# Epoch: 5, Train Loss: 1.431, Val Loss: 1.430, Train Acc: 48.35%, Val Acc: 48.30%, F1 Score: 0.476, Time: 14.29s
# Epoch: 6, Train Loss: 1.382, Val Loss: 1.386, Train Acc: 50.40%, Val Acc: 50.12%, F1 Score: 0.496, Time: 14.45s
# Epoch: 7, Train Loss: 1.340, Val Loss: 1.362, Train Acc: 51.90%, Val Acc: 51.43%, F1 Score: 0.519, Time: 14.27s
# Epoch: 8, Train Loss: 1.301, Val Loss: 1.329, Train Acc: 53.61%, Val Acc: 52.45%, F1 Score: 0.518, Time: 14.40s
# Epoch: 9, Train Loss: 1.266, Val Loss: 1.298, Train Acc: 54.99%, Val Acc: 54.10%, F1 Score: 0.543, Time: 14.34s
# Epoch: 10, Train Loss: 1.237, Val Loss: 1.312, Train Acc: 56.30%, Val Acc: 53.39%, F1 Score: 0.525, Time: 14.43s
# Epoch: 11, Train Loss: 1.214, Val Loss: 1.274, Train Acc: 57.09%, Val Acc: 54.24%, F1 Score: 0.540, Time: 15.60s
# Epoch: 12, Train Loss: 1.187, Val Loss: 1.219, Train Acc: 58.21%, Val Acc: 57.08%, F1 Score: 0.570, Time: 14.60s
# Epoch: 13, Train Loss: 1.163, Val Loss: 1.223, Train Acc: 58.85%, Val Acc: 57.17%, F1 Score: 0.574, Time: 14.34s
# Epoch: 14, Train Loss: 1.141, Val Loss: 1.195, Train Acc: 59.86%, Val Acc: 58.06%, F1 Score: 0.579, Time: 14.35s
# Epoch: 15, Train Loss: 1.120, Val Loss: 1.189, Train Acc: 60.59%, Val Acc: 58.65%, F1 Score: 0.587, Time: 14.39s
# Epoch: 16, Train Loss: 1.104, Val Loss: 1.184, Train Acc: 61.05%, Val Acc: 58.25%, F1 Score: 0.579, Time: 14.07s
# Epoch: 17, Train Loss: 1.085, Val Loss: 1.168, Train Acc: 61.95%, Val Acc: 58.90%, F1 Score: 0.587, Time: 14.20s
# Epoch: 18, Train Loss: 1.069, Val Loss: 1.163, Train Acc: 62.59%, Val Acc: 59.45%, F1 Score: 0.594, Time: 14.30s
# Epoch: 19, Train Loss: 1.055, Val Loss: 1.151, Train Acc: 62.96%, Val Acc: 60.01%, F1 Score: 0.597, Time: 14.19s
# Epoch: 20, Train Loss: 1.039, Val Loss: 1.132, Train Acc: 63.60%, Val Acc: 60.53%, F1 Score: 0.606, Time: 14.30s
# Epoch: 21, Train Loss: 1.023, Val Loss: 1.137, Train Acc: 64.26%, Val Acc: 60.30%, F1 Score: 0.601, Time: 14.30s
# Epoch: 22, Train Loss: 1.013, Val Loss: 1.159, Train Acc: 64.58%, Val Acc: 60.38%, F1 Score: 0.607, Time: 14.27s
# Epoch: 23, Train Loss: 1.000, Val Loss: 1.113, Train Acc: 65.14%, Val Acc: 61.58%, F1 Score: 0.614, Time: 14.15s
# Epoch: 24, Train Loss: 0.982, Val Loss: 1.128, Train Acc: 65.78%, Val Acc: 61.19%, F1 Score: 0.608, Time: 14.17s
# Epoch: 25, Train Loss: 0.968, Val Loss: 1.125, Train Acc: 66.06%, Val Acc: 61.45%, F1 Score: 0.615, Time: 14.23s
# Epoch: 26, Train Loss: 0.958, Val Loss: 1.103, Train Acc: 66.53%, Val Acc: 62.08%, F1 Score: 0.620, Time: 15.57s
# Epoch: 27, Train Loss: 0.946, Val Loss: 1.133, Train Acc: 67.00%, Val Acc: 60.84%, F1 Score: 0.611, Time: 14.34s
# Epoch: 28, Train Loss: 0.937, Val Loss: 1.147, Train Acc: 67.36%, Val Acc: 60.72%, F1 Score: 0.611, Time: 14.23s
# Epoch: 29, Train Loss: 0.921, Val Loss: 1.100, Train Acc: 67.98%, Val Acc: 62.68%, F1 Score: 0.624, Time: 14.43s
# Epoch: 30, Train Loss: 0.910, Val Loss: 1.104, Train Acc: 68.53%, Val Acc: 62.37%, F1 Score: 0.621, Time: 14.15s
# Epoch: 31, Train Loss: 0.897, Val Loss: 1.096, Train Acc: 68.61%, Val Acc: 62.68%, F1 Score: 0.629, Time: 14.26s
# Epoch: 32, Train Loss: 0.887, Val Loss: 1.116, Train Acc: 69.16%, Val Acc: 62.46%, F1 Score: 0.620, Time: 14.23s
# Epoch: 33, Train Loss: 0.877, Val Loss: 1.086, Train Acc: 69.47%, Val Acc: 63.05%, F1 Score: 0.631, Time: 14.10s
# Epoch: 34, Train Loss: 0.861, Val Loss: 1.099, Train Acc: 69.95%, Val Acc: 62.63%, F1 Score: 0.629, Time: 14.23s
# Epoch: 35, Train Loss: 0.852, Val Loss: 1.090, Train Acc: 70.45%, Val Acc: 63.39%, F1 Score: 0.633, Time: 14.16s
# Epoch: 36, Train Loss: 0.847, Val Loss: 1.097, Train Acc: 70.47%, Val Acc: 63.16%, F1 Score: 0.633, Time: 14.08s
# Epoch: 37, Train Loss: 0.831, Val Loss: 1.110, Train Acc: 71.21%, Val Acc: 62.82%, F1 Score: 0.628, Time: 14.16s
# Epoch: 38, Train Loss: 0.818, Val Loss: 1.107, Train Acc: 71.58%, Val Acc: 63.05%, F1 Score: 0.627, Time: 14.13s
# Early stopping triggered at epoch 38
# Test Loss: 1.114, Test Acc: 62.25%, Test F1 Score: 0.619
# Running experiment with ELU activation on MNIST
# Epoch: 1, Train Loss: 0.414, Val Loss: 0.196, Train Acc: 87.67%, Val Acc: 93.89%, F1 Score: 0.939, Time: 14.66s
# Epoch: 2, Train Loss: 0.144, Val Loss: 0.146, Train Acc: 95.66%, Val Acc: 95.50%, F1 Score: 0.955, Time: 15.98s
# Epoch: 3, Train Loss: 0.107, Val Loss: 0.100, Train Acc: 96.80%, Val Acc: 96.88%, F1 Score: 0.968, Time: 14.52s
# Epoch: 4, Train Loss: 0.089, Val Loss: 0.093, Train Acc: 97.29%, Val Acc: 97.05%, F1 Score: 0.970, Time: 14.41s
# Epoch: 5, Train Loss: 0.075, Val Loss: 0.082, Train Acc: 97.72%, Val Acc: 97.38%, F1 Score: 0.974, Time: 14.44s
# Epoch: 6, Train Loss: 0.066, Val Loss: 0.075, Train Acc: 97.95%, Val Acc: 97.58%, F1 Score: 0.976, Time: 14.39s
# Epoch: 7, Train Loss: 0.059, Val Loss: 0.073, Train Acc: 98.12%, Val Acc: 97.67%, F1 Score: 0.977, Time: 14.43s
# Epoch: 8, Train Loss: 0.054, Val Loss: 0.065, Train Acc: 98.33%, Val Acc: 98.00%, F1 Score: 0.980, Time: 14.43s
# Epoch: 9, Train Loss: 0.049, Val Loss: 0.067, Train Acc: 98.47%, Val Acc: 97.94%, F1 Score: 0.979, Time: 14.55s
# Epoch: 10, Train Loss: 0.045, Val Loss: 0.066, Train Acc: 98.60%, Val Acc: 97.90%, F1 Score: 0.979, Time: 14.43s
# Epoch: 11, Train Loss: 0.041, Val Loss: 0.060, Train Acc: 98.72%, Val Acc: 98.16%, F1 Score: 0.981, Time: 14.48s
# Epoch: 12, Train Loss: 0.038, Val Loss: 0.063, Train Acc: 98.83%, Val Acc: 97.94%, F1 Score: 0.979, Time: 14.42s
# Epoch: 13, Train Loss: 0.036, Val Loss: 0.069, Train Acc: 98.82%, Val Acc: 97.92%, F1 Score: 0.979, Time: 14.63s
# Epoch: 14, Train Loss: 0.034, Val Loss: 0.061, Train Acc: 98.93%, Val Acc: 98.18%, F1 Score: 0.982, Time: 14.40s
# Epoch: 15, Train Loss: 0.031, Val Loss: 0.057, Train Acc: 99.05%, Val Acc: 98.21%, F1 Score: 0.982, Time: 14.58s
# Epoch: 16, Train Loss: 0.030, Val Loss: 0.055, Train Acc: 99.08%, Val Acc: 98.33%, F1 Score: 0.983, Time: 15.84s
# Epoch: 17, Train Loss: 0.027, Val Loss: 0.056, Train Acc: 99.15%, Val Acc: 98.28%, F1 Score: 0.983, Time: 14.50s
# Epoch: 18, Train Loss: 0.025, Val Loss: 0.052, Train Acc: 99.22%, Val Acc: 98.28%, F1 Score: 0.983, Time: 14.51s
# Epoch: 19, Train Loss: 0.024, Val Loss: 0.052, Train Acc: 99.25%, Val Acc: 98.38%, F1 Score: 0.984, Time: 14.42s
# Epoch: 20, Train Loss: 0.022, Val Loss: 0.051, Train Acc: 99.33%, Val Acc: 98.59%, F1 Score: 0.986, Time: 14.55s
# Epoch: 21, Train Loss: 0.021, Val Loss: 0.053, Train Acc: 99.37%, Val Acc: 98.44%, F1 Score: 0.984, Time: 14.46s
# Epoch: 22, Train Loss: 0.020, Val Loss: 0.053, Train Acc: 99.40%, Val Acc: 98.44%, F1 Score: 0.984, Time: 14.44s
# Epoch: 23, Train Loss: 0.019, Val Loss: 0.051, Train Acc: 99.46%, Val Acc: 98.42%, F1 Score: 0.984, Time: 14.45s
# Epoch: 24, Train Loss: 0.017, Val Loss: 0.051, Train Acc: 99.51%, Val Acc: 98.53%, F1 Score: 0.985, Time: 14.54s
# Epoch: 25, Train Loss: 0.017, Val Loss: 0.050, Train Acc: 99.51%, Val Acc: 98.43%, F1 Score: 0.984, Time: 14.57s
# Epoch: 26, Train Loss: 0.015, Val Loss: 0.054, Train Acc: 99.58%, Val Acc: 98.53%, F1 Score: 0.985, Time: 14.45s
# Epoch: 27, Train Loss: 0.014, Val Loss: 0.051, Train Acc: 99.58%, Val Acc: 98.47%, F1 Score: 0.985, Time: 14.49s
# Epoch: 28, Train Loss: 0.013, Val Loss: 0.050, Train Acc: 99.65%, Val Acc: 98.59%, F1 Score: 0.986, Time: 14.58s
# Epoch: 29, Train Loss: 0.013, Val Loss: 0.051, Train Acc: 99.64%, Val Acc: 98.60%, F1 Score: 0.986, Time: 14.29s
# Epoch: 30, Train Loss: 0.012, Val Loss: 0.049, Train Acc: 99.67%, Val Acc: 98.63%, F1 Score: 0.986, Time: 14.77s
# Epoch: 31, Train Loss: 0.012, Val Loss: 0.055, Train Acc: 99.67%, Val Acc: 98.47%, F1 Score: 0.985, Time: 14.51s
# Epoch: 32, Train Loss: 0.010, Val Loss: 0.051, Train Acc: 99.74%, Val Acc: 98.56%, F1 Score: 0.985, Time: 14.44s
# Epoch: 33, Train Loss: 0.010, Val Loss: 0.051, Train Acc: 99.76%, Val Acc: 98.55%, F1 Score: 0.985, Time: 14.30s
# Epoch: 34, Train Loss: 0.009, Val Loss: 0.052, Train Acc: 99.77%, Val Acc: 98.53%, F1 Score: 0.985, Time: 14.70s
# Epoch: 35, Train Loss: 0.009, Val Loss: 0.049, Train Acc: 99.76%, Val Acc: 98.62%, F1 Score: 0.986, Time: 14.46s
# Epoch: 36, Train Loss: 0.008, Val Loss: 0.048, Train Acc: 99.80%, Val Acc: 98.71%, F1 Score: 0.987, Time: 14.38s
# Epoch: 37, Train Loss: 0.008, Val Loss: 0.053, Train Acc: 99.83%, Val Acc: 98.54%, F1 Score: 0.985, Time: 14.53s
# Epoch: 38, Train Loss: 0.007, Val Loss: 0.051, Train Acc: 99.84%, Val Acc: 98.58%, F1 Score: 0.986, Time: 14.66s
# Epoch: 39, Train Loss: 0.007, Val Loss: 0.055, Train Acc: 99.81%, Val Acc: 98.58%, F1 Score: 0.986, Time: 14.28s
# Epoch: 40, Train Loss: 0.007, Val Loss: 0.055, Train Acc: 99.85%, Val Acc: 98.63%, F1 Score: 0.986, Time: 14.42s
# Epoch: 41, Train Loss: 0.006, Val Loss: 0.061, Train Acc: 99.90%, Val Acc: 98.39%, F1 Score: 0.984, Time: 14.49s
# Early stopping triggered at epoch 41
# Test Loss: 0.042, Test Acc: 98.78%, Test F1 Score: 0.988
# Running experiment with ELU activation on CIFAR-10
# Epoch: 1, Train Loss: 1.909, Val Loss: 1.734, Train Acc: 31.57%, Val Acc: 38.35%, F1 Score: 0.379, Time: 14.34s
# Epoch: 2, Train Loss: 1.614, Val Loss: 1.550, Train Acc: 41.84%, Val Acc: 44.47%, F1 Score: 0.438, Time: 14.13s
# Epoch: 3, Train Loss: 1.476, Val Loss: 1.472, Train Acc: 46.71%, Val Acc: 47.79%, F1 Score: 0.474, Time: 14.19s
# Epoch: 4, Train Loss: 1.407, Val Loss: 1.413, Train Acc: 49.52%, Val Acc: 49.56%, F1 Score: 0.494, Time: 15.85s
# Epoch: 5, Train Loss: 1.354, Val Loss: 1.369, Train Acc: 51.68%, Val Acc: 50.98%, F1 Score: 0.503, Time: 14.23s
# Epoch: 6, Train Loss: 1.308, Val Loss: 1.338, Train Acc: 53.17%, Val Acc: 52.48%, F1 Score: 0.519, Time: 14.28s
# Epoch: 7, Train Loss: 1.267, Val Loss: 1.297, Train Acc: 54.72%, Val Acc: 54.24%, F1 Score: 0.544, Time: 14.34s
# Epoch: 8, Train Loss: 1.229, Val Loss: 1.263, Train Acc: 56.48%, Val Acc: 55.12%, F1 Score: 0.550, Time: 14.17s
# Epoch: 9, Train Loss: 1.194, Val Loss: 1.236, Train Acc: 57.67%, Val Acc: 55.67%, F1 Score: 0.558, Time: 14.16s
# Epoch: 10, Train Loss: 1.164, Val Loss: 1.224, Train Acc: 58.68%, Val Acc: 56.21%, F1 Score: 0.558, Time: 14.29s
# Epoch: 11, Train Loss: 1.137, Val Loss: 1.186, Train Acc: 59.91%, Val Acc: 57.82%, F1 Score: 0.577, Time: 14.22s
# Epoch: 12, Train Loss: 1.105, Val Loss: 1.166, Train Acc: 61.05%, Val Acc: 58.66%, F1 Score: 0.587, Time: 14.30s
# Epoch: 13, Train Loss: 1.081, Val Loss: 1.204, Train Acc: 62.09%, Val Acc: 57.98%, F1 Score: 0.581, Time: 14.23s
# Epoch: 14, Train Loss: 1.056, Val Loss: 1.125, Train Acc: 62.91%, Val Acc: 60.22%, F1 Score: 0.603, Time: 14.12s
# Epoch: 15, Train Loss: 1.037, Val Loss: 1.119, Train Acc: 63.72%, Val Acc: 60.70%, F1 Score: 0.607, Time: 14.28s
# Epoch: 16, Train Loss: 1.016, Val Loss: 1.103, Train Acc: 64.34%, Val Acc: 61.00%, F1 Score: 0.609, Time: 14.11s
# Epoch: 17, Train Loss: 0.999, Val Loss: 1.087, Train Acc: 65.04%, Val Acc: 61.92%, F1 Score: 0.618, Time: 14.21s
# Epoch: 18, Train Loss: 0.978, Val Loss: 1.086, Train Acc: 65.97%, Val Acc: 62.18%, F1 Score: 0.621, Time: 14.17s
# Epoch: 19, Train Loss: 0.961, Val Loss: 1.080, Train Acc: 66.28%, Val Acc: 62.02%, F1 Score: 0.617, Time: 15.72s
# Epoch: 20, Train Loss: 0.948, Val Loss: 1.062, Train Acc: 66.90%, Val Acc: 63.13%, F1 Score: 0.634, Time: 14.21s
# Epoch: 21, Train Loss: 0.930, Val Loss: 1.054, Train Acc: 67.59%, Val Acc: 63.22%, F1 Score: 0.626, Time: 14.21s
# Epoch: 22, Train Loss: 0.916, Val Loss: 1.054, Train Acc: 67.94%, Val Acc: 63.25%, F1 Score: 0.634, Time: 14.05s
# Epoch: 23, Train Loss: 0.902, Val Loss: 1.054, Train Acc: 68.43%, Val Acc: 63.20%, F1 Score: 0.628, Time: 14.21s
# Epoch: 24, Train Loss: 0.888, Val Loss: 1.043, Train Acc: 69.02%, Val Acc: 63.79%, F1 Score: 0.636, Time: 14.10s
# Epoch: 25, Train Loss: 0.874, Val Loss: 1.030, Train Acc: 69.37%, Val Acc: 64.29%, F1 Score: 0.642, Time: 14.18s
# Epoch: 26, Train Loss: 0.860, Val Loss: 1.028, Train Acc: 69.64%, Val Acc: 64.48%, F1 Score: 0.643, Time: 14.31s
# Epoch: 27, Train Loss: 0.847, Val Loss: 1.044, Train Acc: 70.41%, Val Acc: 64.17%, F1 Score: 0.641, Time: 14.18s
# Epoch: 28, Train Loss: 0.836, Val Loss: 1.040, Train Acc: 70.83%, Val Acc: 64.53%, F1 Score: 0.646, Time: 14.20s
# Epoch: 29, Train Loss: 0.824, Val Loss: 1.026, Train Acc: 71.22%, Val Acc: 64.75%, F1 Score: 0.648, Time: 14.21s
# Epoch: 30, Train Loss: 0.814, Val Loss: 1.032, Train Acc: 71.74%, Val Acc: 64.77%, F1 Score: 0.649, Time: 14.27s
# Epoch: 31, Train Loss: 0.800, Val Loss: 1.044, Train Acc: 72.00%, Val Acc: 64.15%, F1 Score: 0.643, Time: 14.23s
# Epoch: 32, Train Loss: 0.788, Val Loss: 1.038, Train Acc: 72.55%, Val Acc: 64.48%, F1 Score: 0.644, Time: 14.18s
# Epoch: 33, Train Loss: 0.777, Val Loss: 1.029, Train Acc: 73.10%, Val Acc: 65.15%, F1 Score: 0.649, Time: 14.17s
# Epoch: 34, Train Loss: 0.765, Val Loss: 1.032, Train Acc: 73.28%, Val Acc: 65.42%, F1 Score: 0.654, Time: 15.51s
# Early stopping triggered at epoch 34
# Test Loss: 1.023, Test Acc: 65.42%, Test F1 Score: 0.654
# Running experiment with SeLU activation on MNIST
# Epoch: 1, Train Loss: 0.340, Val Loss: 0.176, Train Acc: 89.69%, Val Acc: 94.46%, F1 Score: 0.944, Time: 14.64s
# Epoch: 2, Train Loss: 0.134, Val Loss: 0.124, Train Acc: 95.91%, Val Acc: 96.03%, F1 Score: 0.960, Time: 14.38s
# Epoch: 3, Train Loss: 0.098, Val Loss: 0.099, Train Acc: 97.00%, Val Acc: 96.92%, F1 Score: 0.969, Time: 14.40s
# Epoch: 4, Train Loss: 0.080, Val Loss: 0.087, Train Acc: 97.50%, Val Acc: 97.27%, F1 Score: 0.972, Time: 14.57s
# Epoch: 5, Train Loss: 0.068, Val Loss: 0.078, Train Acc: 97.92%, Val Acc: 97.58%, F1 Score: 0.976, Time: 14.57s
# Epoch: 6, Train Loss: 0.058, Val Loss: 0.073, Train Acc: 98.16%, Val Acc: 97.78%, F1 Score: 0.978, Time: 14.61s
# Epoch: 7, Train Loss: 0.052, Val Loss: 0.074, Train Acc: 98.35%, Val Acc: 97.71%, F1 Score: 0.977, Time: 14.37s
# Epoch: 8, Train Loss: 0.048, Val Loss: 0.065, Train Acc: 98.52%, Val Acc: 97.94%, F1 Score: 0.979, Time: 14.43s
# Epoch: 9, Train Loss: 0.043, Val Loss: 0.068, Train Acc: 98.65%, Val Acc: 97.92%, F1 Score: 0.979, Time: 14.35s
# Epoch: 10, Train Loss: 0.040, Val Loss: 0.065, Train Acc: 98.78%, Val Acc: 98.01%, F1 Score: 0.980, Time: 14.50s
# Epoch: 11, Train Loss: 0.036, Val Loss: 0.062, Train Acc: 98.88%, Val Acc: 98.07%, F1 Score: 0.980, Time: 14.44s
# Epoch: 12, Train Loss: 0.033, Val Loss: 0.061, Train Acc: 98.97%, Val Acc: 98.11%, F1 Score: 0.981, Time: 14.28s
# Epoch: 13, Train Loss: 0.031, Val Loss: 0.064, Train Acc: 99.04%, Val Acc: 97.97%, F1 Score: 0.979, Time: 14.47s
# Epoch: 14, Train Loss: 0.029, Val Loss: 0.058, Train Acc: 99.10%, Val Acc: 98.33%, F1 Score: 0.983, Time: 17.16s
# Epoch: 15, Train Loss: 0.027, Val Loss: 0.059, Train Acc: 99.19%, Val Acc: 98.28%, F1 Score: 0.983, Time: 14.48s
# Epoch: 16, Train Loss: 0.025, Val Loss: 0.056, Train Acc: 99.29%, Val Acc: 98.41%, F1 Score: 0.984, Time: 14.41s
# Epoch: 17, Train Loss: 0.023, Val Loss: 0.056, Train Acc: 99.33%, Val Acc: 98.36%, F1 Score: 0.983, Time: 14.52s
# Epoch: 18, Train Loss: 0.021, Val Loss: 0.054, Train Acc: 99.37%, Val Acc: 98.36%, F1 Score: 0.983, Time: 15.06s
# Epoch: 19, Train Loss: 0.020, Val Loss: 0.054, Train Acc: 99.39%, Val Acc: 98.42%, F1 Score: 0.984, Time: 14.38s
# Epoch: 20, Train Loss: 0.019, Val Loss: 0.053, Train Acc: 99.40%, Val Acc: 98.46%, F1 Score: 0.984, Time: 14.39s
# Epoch: 21, Train Loss: 0.017, Val Loss: 0.054, Train Acc: 99.51%, Val Acc: 98.42%, F1 Score: 0.984, Time: 14.58s
# Epoch: 22, Train Loss: 0.016, Val Loss: 0.056, Train Acc: 99.51%, Val Acc: 98.40%, F1 Score: 0.984, Time: 14.37s
# Epoch: 23, Train Loss: 0.015, Val Loss: 0.056, Train Acc: 99.57%, Val Acc: 98.40%, F1 Score: 0.984, Time: 14.28s
# Epoch: 24, Train Loss: 0.014, Val Loss: 0.055, Train Acc: 99.61%, Val Acc: 98.58%, F1 Score: 0.986, Time: 14.59s
# Epoch: 25, Train Loss: 0.013, Val Loss: 0.053, Train Acc: 99.63%, Val Acc: 98.53%, F1 Score: 0.985, Time: 14.46s
# Early stopping triggered at epoch 25
# Test Loss: 0.038, Test Acc: 98.81%, Test F1 Score: 0.988
# Running experiment with SeLU activation on CIFAR-10
# Epoch: 1, Train Loss: 1.777, Val Loss: 1.620, Train Acc: 36.33%, Val Acc: 42.14%, F1 Score: 0.417, Time: 14.16s
# Epoch: 2, Train Loss: 1.531, Val Loss: 1.496, Train Acc: 44.88%, Val Acc: 46.51%, F1 Score: 0.462, Time: 14.18s
# Epoch: 3, Train Loss: 1.434, Val Loss: 1.448, Train Acc: 48.96%, Val Acc: 48.57%, F1 Score: 0.485, Time: 14.31s
# Epoch: 4, Train Loss: 1.375, Val Loss: 1.380, Train Acc: 51.07%, Val Acc: 50.99%, F1 Score: 0.505, Time: 15.06s
# Epoch: 5, Train Loss: 1.320, Val Loss: 1.352, Train Acc: 53.22%, Val Acc: 52.27%, F1 Score: 0.515, Time: 14.30s
# Epoch: 6, Train Loss: 1.275, Val Loss: 1.323, Train Acc: 55.17%, Val Acc: 53.52%, F1 Score: 0.530, Time: 14.39s
# Epoch: 7, Train Loss: 1.233, Val Loss: 1.254, Train Acc: 56.37%, Val Acc: 55.94%, F1 Score: 0.557, Time: 14.30s
# Epoch: 8, Train Loss: 1.202, Val Loss: 1.257, Train Acc: 57.59%, Val Acc: 56.42%, F1 Score: 0.564, Time: 14.28s
# Epoch: 9, Train Loss: 1.165, Val Loss: 1.213, Train Acc: 58.75%, Val Acc: 57.78%, F1 Score: 0.579, Time: 14.26s
# Epoch: 10, Train Loss: 1.139, Val Loss: 1.195, Train Acc: 59.84%, Val Acc: 57.51%, F1 Score: 0.570, Time: 14.22s
# Epoch: 11, Train Loss: 1.115, Val Loss: 1.185, Train Acc: 60.76%, Val Acc: 58.29%, F1 Score: 0.581, Time: 14.17s
# Epoch: 12, Train Loss: 1.089, Val Loss: 1.180, Train Acc: 61.56%, Val Acc: 58.63%, F1 Score: 0.587, Time: 14.29s
# Epoch: 13, Train Loss: 1.062, Val Loss: 1.209, Train Acc: 62.37%, Val Acc: 58.00%, F1 Score: 0.581, Time: 14.32s
# Epoch: 14, Train Loss: 1.038, Val Loss: 1.126, Train Acc: 63.76%, Val Acc: 60.61%, F1 Score: 0.606, Time: 14.29s
# Epoch: 15, Train Loss: 1.020, Val Loss: 1.132, Train Acc: 64.16%, Val Acc: 60.43%, F1 Score: 0.604, Time: 14.21s
# Epoch: 16, Train Loss: 1.002, Val Loss: 1.111, Train Acc: 64.87%, Val Acc: 61.14%, F1 Score: 0.611, Time: 14.42s
# Epoch: 17, Train Loss: 0.985, Val Loss: 1.094, Train Acc: 65.39%, Val Acc: 61.98%, F1 Score: 0.617, Time: 14.33s
# Epoch: 18, Train Loss: 0.965, Val Loss: 1.103, Train Acc: 66.28%, Val Acc: 61.64%, F1 Score: 0.615, Time: 14.34s
# Epoch: 19, Train Loss: 0.949, Val Loss: 1.086, Train Acc: 66.69%, Val Acc: 62.12%, F1 Score: 0.620, Time: 14.24s
# Epoch: 20, Train Loss: 0.934, Val Loss: 1.073, Train Acc: 67.26%, Val Acc: 62.82%, F1 Score: 0.629, Time: 15.15s
# Epoch: 21, Train Loss: 0.916, Val Loss: 1.079, Train Acc: 67.92%, Val Acc: 63.00%, F1 Score: 0.625, Time: 14.28s
# Epoch: 22, Train Loss: 0.901, Val Loss: 1.072, Train Acc: 68.56%, Val Acc: 63.22%, F1 Score: 0.631, Time: 14.24s
# Epoch: 23, Train Loss: 0.893, Val Loss: 1.075, Train Acc: 68.81%, Val Acc: 62.90%, F1 Score: 0.624, Time: 14.32s
# Epoch: 24, Train Loss: 0.874, Val Loss: 1.081, Train Acc: 69.47%, Val Acc: 63.06%, F1 Score: 0.627, Time: 14.35s
# Epoch: 25, Train Loss: 0.860, Val Loss: 1.074, Train Acc: 69.83%, Val Acc: 63.31%, F1 Score: 0.632, Time: 14.18s
# Epoch: 26, Train Loss: 0.846, Val Loss: 1.060, Train Acc: 70.47%, Val Acc: 63.73%, F1 Score: 0.637, Time: 14.32s
# Epoch: 27, Train Loss: 0.834, Val Loss: 1.067, Train Acc: 70.85%, Val Acc: 63.57%, F1 Score: 0.636, Time: 14.26s
# Epoch: 28, Train Loss: 0.821, Val Loss: 1.069, Train Acc: 71.39%, Val Acc: 63.17%, F1 Score: 0.630, Time: 14.35s
# Epoch: 29, Train Loss: 0.807, Val Loss: 1.068, Train Acc: 71.54%, Val Acc: 63.94%, F1 Score: 0.639, Time: 14.21s
# Epoch: 30, Train Loss: 0.800, Val Loss: 1.059, Train Acc: 72.18%, Val Acc: 64.18%, F1 Score: 0.641, Time: 14.34s
# Epoch: 31, Train Loss: 0.782, Val Loss: 1.083, Train Acc: 72.63%, Val Acc: 62.95%, F1 Score: 0.631, Time: 14.29s
# Epoch: 32, Train Loss: 0.775, Val Loss: 1.062, Train Acc: 72.94%, Val Acc: 64.30%, F1 Score: 0.641, Time: 14.24s
# Epoch: 33, Train Loss: 0.764, Val Loss: 1.076, Train Acc: 73.20%, Val Acc: 63.88%, F1 Score: 0.636, Time: 14.32s
# Epoch: 34, Train Loss: 0.752, Val Loss: 1.068, Train Acc: 73.45%, Val Acc: 64.33%, F1 Score: 0.642, Time: 14.34s
# Epoch: 35, Train Loss: 0.741, Val Loss: 1.069, Train Acc: 74.08%, Val Acc: 64.16%, F1 Score: 0.642, Time: 15.92s
# Early stopping triggered at epoch 35
# Test Loss: 1.083, Test Acc: 62.98%, Test F1 Score: 0.629

# %% [markdown]
# ### Dataframe 저장

# %%
for name, result in results_mnist.items():
  results_df = result[0]
  gradients_df = result[1]
  results_df.to_csv(f'./final_SGD/{name}-result-mnist.csv')
  gradients_df.to_csv(f'./final_SGD/{name}-grad-mnist.csv')

# %%
for name, result in results_cifar10.items():
  results_df = result[0]
  gradients_df = result[1]
  results_df.to_csv(f'./final_SGD/{name}-result-cifar10.csv')
  gradients_df.to_csv(f'./final_SGD/{name}-grad-cifar10.csv')

# %%
# Test 결과 저장
def save_test_results_to_dataframe(results, filename):
    data = {
        'Activation Function': [],
        'Test Accuracy': [],
        'Test Loss': [],
        'Test F1 Score': []
    }

    for activation_name, result in results.items():
        data['Activation Function'].append(activation_name)
        data['Test Accuracy'].append(result[2]['test_acc'])
        data['Test Loss'].append(result[2]['test_loss'])
        data['Test F1 Score'].append(result[2]['test_f1'])

    df = pd.DataFrame(data)
    df.to_csv(filename, index=False)

save_test_results_to_dataframe(results_mnist, './final_SGD/test-mnist.csv')
save_test_results_to_dataframe(results_cifar10, './final_SGD/test-cifar10.csv')

# %% [markdown]
# ### Loss, Acc, F1-score 시각화 (그래프)

# %%
# loss, acc, f1 score
def plot_results_1(results, title):
    plt.figure(figsize=(20, 5))

    plt.subplot(1, 3, 1)
    for name, result in results.items():
        plt.plot(result[0]['val_loss'], label=f'{name} Val Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title(f'{title} - Loss')
    plt.legend()

    plt.subplot(1, 3, 2)
    for name, result in results.items():
        plt.plot(result[0]['val_acc'], label=f'{name} Val Acc')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.title(f'{title} - Accuracy')
    plt.legend()

    plt.subplot(1, 3, 3)
    for name, result in results.items():
        plt.plot(result[0]['f1_scores'], label=f'{name} F1 Score')
    plt.xlabel('Epoch')
    plt.ylabel('F1 Score')
    plt.title(f'{title} - F1 Score')
    plt.legend()

    plt.show()

plot_results_1(results_mnist, 'MNIST')
plot_results_1(results_cifar10, 'CIFAR-10')

# %% [markdown]
# ### Gradient 시각화
#   - 층마다 평균 가중치 시각화

# %%
def plot_gradients(results, title):
    # 레이어와 활성화 함수 이름
    layers = ['conv1.weight', 'conv2.weight', 'fc1.weight', 'fc2.weight', 'fc3.weight']
    activation_functions = list(results.keys())

    # 시각화
    fig, axs = plt.subplots(1, 5, figsize=(20, 5))

    for i, layer in enumerate(layers):
        for activation in activation_functions:
            axs[i].plot(results[activation][1][layer], label=activation)
        axs[i].set_title(f'{title}-Gradients for {layer}')
        axs[i].set_xlabel('Epoch')
        axs[i].set_ylabel('Gradient L2 Norm')
        axs[i].legend()

    plt.tight_layout()
    plt.show()

plot_gradients(results_mnist, 'MNIST')
plot_gradients(results_cifar10, 'CIFAR-10')

# %% [markdown]
# ### 학습 시간
#   - 전체 시간, Epoch 평균

# %%
def pd_time(results):
    results_list = {'sigmoid': [],
                    'ReLU': [],
                    'LReLU': [],
                    'ELU': [],
                    'SeLU': []}
    for name, result in results.items():
        epoch = len(result[0]['epoch_times'])
        all = sum(result[0]['epoch_times'])
        avg = all / epoch
        results_list[name] = [all, avg]

    return pd.DataFrame(results_list, index = ['전체 시간', '평균 시간'])

# %%
time_mnist = pd_time(results_mnist)
time_mnist.to_csv('./final_SGD/time-mnist.csv')
time_cifar10 = pd_time(results_cifar10)
time_cifar10.to_csv('./final_SGD/time-cifar10.csv')
print("MNIST Training Times:")
print(time_mnist)
print("\nCIFAR-10 Training Times:")
print(time_cifar10)
# Out:
# MNIST Training Times:
#           sigmoid        ReLU       LReLU         ELU        SeLU
# 전체 시간  727.055606  393.457989  393.709648  596.763298  364.671788
# 평균 시간   14.541112   14.572518   14.581839   14.555202   14.586872
#
# CIFAR-10 Training Times:
#           sigmoid        ReLU       LReLU         ELU        SeLU
# 전체 시간  715.624771  603.537946  545.273922  487.569497  503.182495
# 평균 시간   14.312495   14.369951   14.349314   14.340279   14.376643

# %% [markdown]
# ### Test 결과

# %%
mnist_test_results_df = pd.read_csv('./final_SGD/test-mnist.csv')
cifar10_test_results_df = pd.read_csv('./final_SGD/test-cifar10.csv')

print("MNIST Test Results:")
print(mnist_test_results_df)

print("\nCIFAR-10 Test Results:")
print(cifar10_test_results_df)
# Out:
# MNIST Test Results:
#   Activation Function  Test Accuracy  Test Loss  Test F1 Score
# 0             sigmoid          94.22   0.206751       0.941605
# 1                ReLU          98.35   0.053706       0.983277
# 2               LReLU          98.26   0.056802       0.982377
# 3                 ELU          98.78   0.042294       0.987709
# 4                SeLU          98.81   0.037513       0.988012
#
# CIFAR-10 Test Results:
#   Activation Function  Test Accuracy  Test Loss  Test F1 Score
# 0             sigmoid          28.45   1.945155       0.235885
# 1                ReLU          62.30   1.136866       0.623900
# 2               LReLU          62.25   1.114485       0.619075
# 3                 ELU          65.42   1.023096       0.653599
# 4                SeLU          62.98   1.082719       0.629210
